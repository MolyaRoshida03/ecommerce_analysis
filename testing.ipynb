# %%
import os


import mysql.connector
# from mysql imprt connector
from dotenv import load_dotenv

import pandas as pd

# %%
load_dotenv()

#print(os.getenv('USER'))
user = os.getenv('USER')
password = os.getenv('PASSWORD')
host = os.getenv('HOST')
database = 'swiftmarket'

# %%
connection = mysql.connector.connect(user = user,
                                     password = password,
                                     host=host,
                                     database = database)
cursor = connection.cursor()

# %%
connection.is_connected()
# Out:
# True

# %%
query = '''show tables'''
cursor.execute(query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('categories',)
# ('customers',)
# ('employees',)
# ('salesdata',)
# ('subcategories',)
# ('suppliers',)

# %%
def func():
    result = pd.DataFrame(data=rows, columns=cursor.column_names)

    return result
func()
# Out:
#   Tables_in_swiftmarket
# 0            categories
# 1             customers
# 2             employees
# 3             salesdata
# 4         subcategories
# 5             suppliers

# %%
def read_query(query):
    
    cursor.execute(query)
    rows = cursor.fetchall()
    
    return pd.DataFrame(data=rows, columns=cursor.column_names)

# %%
query = '''select * from categories limit 5'''
read_query(query)
# Out:
#    CategoryID                     CategoryName
# 0      500100          Electronics and Gadgets
# 1      500101      Home and Kitchen Appliances
# 2      500102     Outdoor and Sports Equipment
# 3      500103     Health and Wellness Products
# 4      500104  Books and Educational Materials

# %%
query = '''select * from customers limit 5'''
read_query(query)
# Out:
#        CustomerID FirstName  LastName                      Email  \
# 0    C-2023-100-1    Mahika    Sunder  MahikaSunder_11@zmail.com
# 1   C-2023-100-10   Zeeshan      Vasa    ZeeshanVasa_1@zmail.com
# 2  C-2023-100-100     Aaina  Sachdeva  AainaSachdeva_9@zmail.com
# 3  C-2023-100-101     Shray     Bajwa    ShrayBajwa_11@zmail.com
# 4  C-2023-100-102     Navya      Dash      NavyaDash_5@zmail.com
#
#            Phone            Address     State
# 0    03412176590   H.No. 155, Chana     Assam
# 1  +911151051656      52, Roy Nagar   Tripura
# 2  +918834507719   75/92, Kade Marg  Nagaland
# 3    07410498662      45, Bora Ganj   Manipur
# 4  +917644200850  70/782\nBahl Road    Kerala

# %%
query = '''select s.saledate,c.firstname,s.totalprice 
from salesdata s
join customers c
on s.customerid=c.customerid
order by s.saledate;'''
read_query(query)
# Out:
#          saledate firstname totalprice
# 0      2023-01-01     Shalv  208626.00
# 1      2023-01-01     Kiara   28797.00
# 2      2023-01-01    Ranbir   70235.00
# 3      2023-01-01     Shray  104188.00
# 4      2023-01-01   Samarth   69694.00
# ...           ...       ...        ...
# 11996  2023-12-30     Gatik  347710.00
# 11997  2023-12-30  Indrajit  136720.00
# 11998  2023-12-30      Azad  111075.00
# 11999  2023-12-30     Sahil   99402.00
# 12000  2023-12-30      Tiya   74970.00
#
# [12001 rows x 3 columns]

# %%
query = """select * from employees;"""

query = """select firstname, email
           from employees limit 5;"""

read_query(query)
# Out:
#   firstname                   email
# 0     Fateh  fname.lname@swiftm.org
# 1    Chirag  fname.lname@swiftm.org
# 2   Dhanush  fname.lname@swiftm.org
# 3     Anika  fname.lname@swiftm.org
# 4      Keya  fname.lname@swiftm.org

# %%
query = 'select * from customers limit 4;'
read_query(query)
# Out:
#        CustomerID FirstName  LastName                      Email  \
# 0    C-2023-100-1    Mahika    Sunder  MahikaSunder_11@zmail.com
# 1   C-2023-100-10   Zeeshan      Vasa    ZeeshanVasa_1@zmail.com
# 2  C-2023-100-100     Aaina  Sachdeva  AainaSachdeva_9@zmail.com
# 3  C-2023-100-101     Shray     Bajwa    ShrayBajwa_11@zmail.com
#
#            Phone           Address     State
# 0    03412176590  H.No. 155, Chana     Assam
# 1  +911151051656     52, Roy Nagar   Tripura
# 2  +918834507719  75/92, Kade Marg  Nagaland
# 3    07410498662     45, Bora Ganj   Manipur

# %%
query = 'show tables;'
read_query(query)
# Out:
#   Tables_in_swiftmarket
# 0            categories
# 1             customers
# 2             employees
# 3             salesdata
# 4         subcategories
# 5             suppliers

# %%
query = """Select * from salesdata limit 3;"""
read_query(query)
# Out:
#    SaleID      CustomerID  SubcatID  EmployeeID    SaleDate  Quantity  \
# 0   23000   C-2023-100-12      6002        1100  2023-05-02         2
# 1   23001  C-2023-100-141      6029        1115  2023-12-26         2
# 2   23002   C-2023-100-86      6029        1035  2023-03-26         2
#
#   TotalPrice
# 0  176432.00
# 1   47172.00
# 2   47172.00

# %%
query = """Select s.customerid, c.firstname,s.saledate,s.totalprice
from salesdata s
join customers c
on s.customerid = c.customerid
limit 5;"""

read_query(query)
# Out:
#      customerid firstname    saledate totalprice
# 0  C-2023-100-1    Mahika  2023-07-22   67312.00
# 1  C-2023-100-1    Mahika  2023-05-23  176466.00
# 2  C-2023-100-1    Mahika  2023-11-26  190332.00
# 3  C-2023-100-1    Mahika  2023-03-31  205080.00
# 4  C-2023-100-1    Mahika  2023-11-22   14174.00

# %%
query = 'show tables;'
read_query(query)
# Out:
#   Tables_in_swiftmarket
# 0            categories
# 1             customers
# 2             employees
# 3             salesdata
# 4         subcategories
# 5             suppliers

# %%
query = 'select * from salesdata limit 10;'
read_query(query)
# Out:
#    SaleID      CustomerID  SubcatID  EmployeeID    SaleDate  Quantity  \
# 0   23000   C-2023-100-12      6002        1100  2023-05-02         2
# 1   23001  C-2023-100-141      6029        1115  2023-12-26         2
# 2   23002   C-2023-100-86      6029        1035  2023-03-26         2
# 3   23003   C-2023-100-72      6006        1016  2023-08-01         2
# 4   23004  C-2023-100-142      6030        1067  2023-03-06         5
# 5   23005   C-2023-100-72      6015        1012  2023-11-22         5
# 6   23006   C-2023-100-78      6015        1044  2023-10-26         5
# 7   23007   C-2023-100-36      6017        1018  2023-03-29         5
# 8   23008  C-2023-100-147      6030        1049  2023-01-17         3
# 9   23009    C-2023-100-7      6019        1047  2023-07-19         4
#
#   TotalPrice
# 0  176432.00
# 1   47172.00
# 2   47172.00
# 3  117644.00
# 4  336560.00
# 5  396935.00
# 6  396935.00
# 7  295510.00
# 8  201936.00
# 9   56188.00
